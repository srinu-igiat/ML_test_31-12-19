# %%
import pandas as pd

# %%
df=pd.read_csv("testData.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001015    Male     Yes          0      Graduate            No
# 1    LP001022    Male     Yes          1      Graduate            No
# 2    LP001031    Male     Yes          2      Graduate            No
# 3    LP001035    Male     Yes          2      Graduate            No
# 4    LP001051    Male      No          0  Not Graduate            No
# 5    LP001054    Male     Yes          0  Not Graduate           Yes
# 6    LP001055  Female      No          1  Not Graduate            No
# 7    LP001056    Male     Yes          2  Not Graduate            No
# 8    LP001059    Male     Yes          2      Graduate           NaN
# 9    LP001067    Male      No          0  Not Graduate            No
# 10   LP001078    Male      No          0  Not Graduate            No
# 11   LP001082    Male     Yes          1      Graduate           NaN
# 12   LP001083    Male      No         3+      Graduate            No
# ...

# %%
df.keys()
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
df1=pd.read_csv("trainData.csv")
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
df1.shape
# Out:
# (614, 13)

# %%
df2=df.append(df1)     # combined of both data sets
df2
# Out:
# C:\Users\SRINU\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#      ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 0               5720                0.0             1.0          0
# 1               3076             1500.0             1.0          1
# 2               5000             1800.0             1.0          2
# 4               3276                0.0             1.0          0
# 5               2165             3422.0             1.0          0
# 6               2226                0.0             1.0          1
# 7               3881                0.0             0.0          2
# 9               2400             2400.0             1.0          0
# ...

# %%
df2.shape
# Out:
# (903, 13)

# %%
df2["Gender"].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df3=df2["Gender"][df2["Gender"]=="Male"]=="Femail"

# %%
df3
# Out:
# 0      False
# 1      False
# 2      False
# 4      False
# 5      False
# 7      False
# 9      False
# 10     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 24     False
# 25     False
# 27     False
# 29     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 37     False
# 38     False
# 39     False
# 40     False
# 42     False
# 43     False
# 47     False
#        ...
# 575    False
# 577    False
# 578    False
# 579    False
# 580    False
# 581    False
# 583    False
# 584    False
# 585    False
# 586    False
# 589    False
# 590    False
# 591    False
# 593    False
# 594    False
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# 601    False
# 602    False
# 603    False
# 605    False
# 606    False
# 607    False
# 608    False
# 610    False
# 611    False
# 612    False
# Name: Gender, Length: 719, dtype: bool

# %%
df2
# Out:
#      ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 0               5720                0.0             1.0          0
# 1               3076             1500.0             1.0          1
# 2               5000             1800.0             1.0          2
# 4               3276                0.0             1.0          0
# 5               2165             3422.0             1.0          0
# 6               2226                0.0             1.0          1
# 7               3881                0.0             0.0          2
# 9               2400             2400.0             1.0          0
# 10              3091                0.0             1.0          0
# 14              4666                0.0             1.0          0
# 15              5667                0.0             1.0          1
# 16              4583             2916.0             1.0          2
# 17              3786              333.0             1.0         3+
# ...

# %%
df2.keys()
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'Credit_History', 'Dependents',
#        'Education', 'Gender', 'LoanAmount', 'Loan_Amount_Term', 'Loan_ID',
#        'Loan_Status', 'Married', 'Property_Area', 'Self_Employed'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
lab = LabelEncoder()
df2['Education1'] = lab.fit_transform(df2['Education'])

# %%
lab.classes_
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df4=pd.get_dummies(df2,columns=["Married","Gender","Dependents","Education","Self_Employed","Property_Area"],drop_first=True)

# %%
df4.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  Credit_History  LoanAmount  \
# 0             5720                0.0             1.0       110.0
# 1             3076             1500.0             1.0       126.0
# 2             5000             1800.0             1.0       208.0
# 4             3276                0.0             1.0        78.0
# 5             2165             3422.0             1.0       152.0
#
#    Loan_Amount_Term   Loan_ID Loan_Status  Married_Yes  Gender_Male  \
# 0             360.0  LP001015         NaN            1            1
# 1             360.0  LP001022         NaN            1            1
# 2             360.0  LP001031         NaN            1            1
# 4             360.0  LP001051         NaN            0            1
# 5             360.0  LP001054         NaN            1            1
#
#    Dependents_1  Dependents_2  Dependents_3+  Education_Not Graduate  \
# 0             0             0              0                       0
# ...

# %%
df4
# Out:
#      ApplicantIncome  CoapplicantIncome  Credit_History  LoanAmount  \
# 0               5720                0.0             1.0       110.0
# 1               3076             1500.0             1.0       126.0
# 2               5000             1800.0             1.0       208.0
# 4               3276                0.0             1.0        78.0
# 5               2165             3422.0             1.0       152.0
# 6               2226                0.0             1.0        59.0
# 7               3881                0.0             0.0       147.0
# 9               2400             2400.0             1.0       123.0
# 10              3091                0.0             1.0        90.0
# 14              4666                0.0             1.0       124.0
# 15              5667                0.0             1.0       131.0
# 16              4583             2916.0             1.0       200.0
# 17              3786              333.0             1.0       126.0
# ...

# %%
df4["Gender_male"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender_male'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-02edda6aab57> in <module>
# ----> 1 df4["Gender_male"].value_counts()
#
# ...

# %%
print(df4).sample(5)
# Out:
#      ApplicantIncome  CoapplicantIncome  Credit_History  LoanAmount  \
# 0               5720                0.0             1.0       110.0
# 1               3076             1500.0             1.0       126.0
# 2               5000             1800.0             1.0       208.0
# 4               3276                0.0             1.0        78.0
# 5               2165             3422.0             1.0       152.0
# 6               2226                0.0             1.0        59.0
# 7               3881                0.0             0.0       147.0
# 9               2400             2400.0             1.0       123.0
# 10              3091                0.0             1.0        90.0
# 14              4666                0.0             1.0       124.0
# 15              5667                0.0             1.0       131.0
# 16              4583             2916.0             1.0       200.0
# 17              3786              333.0             1.0       126.0
# ...

# %%
df.dropna(inplace=True)

# %%
X=df4[["LoanAmount"]]

# %%
X.sample(4)
# Out:
#      LoanAmount
# 75        113.0
# 45         88.0
# 411       160.0
# 154        72.0

# %%
y=df4['Married_Yes']

# %%
y.sample(3)
# Out:
# 19     1
# 33     1
# 186    1
# Name: Married_Yes, dtype: uint8

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=40)

# %%
X_train.shape
# Out:
# (632, 1)

# %%
y_train.shape
# Out:
# (632,)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
testData= DecisionTreeClassifier()

# %%
y.unique()
# Out:
# array([1, 0], dtype=uint64)

# %%
testData.predict(X)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-88-8c3247ec7926> in <module>
# ----> 1 testData.predict(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in predict(self, X, check_input)
#     427             The predicted classes, or the predict values.
#     428         """
# --> 429         check_is_fitted(self, 'tree_')
#     430         X = self._validate_X_predict(X, check_input)
#     431         proba = self.tree_.predict(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     912
#     913     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 914         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     915
#     916
#
# ...
